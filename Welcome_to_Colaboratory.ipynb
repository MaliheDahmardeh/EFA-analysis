# %% [markdown]
# <a href="https://colab.research.google.com/github/MaliheDahmardeh/EFA-analysis/blob/main/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install factor-analyzer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #Import Libraries

# %%
import numpy as np
from pandas.core.algorithms import mode
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# #Import Dataset

# %%
# !ls
# Out:
# 'Dataset EFA.csv'   sample_data

# %%
df = pd.read_csv('Dataset EFA.csv' )

# %%
df
# Out:
#        race  age  engnat  gender  hand  source country  E1  E2  E3  ...  O1  \
# 0         3   53       1       1     1       1      US   4   2   5  ...   4
# 1        13   46       1       2     1       1      US   2   2   3  ...   3
# 2         1   14       2       2     1       1      PK   5   1   1  ...   4
# 3         3   19       2       2     1       1      RO   2   5   2  ...   4
# 4        11   25       2       2     1       2      US   3   1   3  ...   3
# ...     ...  ...     ...     ...   ...     ...     ...  ..  ..  ..  ...  ..
# 19714    11   15       1       2     1       2      SG   1   4   3  ...   1
# 19715     3   37       1       2     1       2      US   2   3   2  ...   1
# 19716     5   16       2       1     1       2      US   2   5   4  ...   5
# 19717    12   16       1       1     1       5      NG   1   4   2  ...   3
# 19718     3   35       1       1     1       1      US   2   3   1  ...   5
#
#        O2  O3  O4  O5  O6  O7  O8  O9  O10
# ...

# %%
df.columns
# Out:
# Index(['race', 'age', 'engnat', 'gender', 'hand', 'source', 'country', 'E1',
#        'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'N1', 'N2', 'N3',
#        'N4', 'N5', 'N6', 'N7', 'N8', 'N9', 'N10', 'A1', 'A2', 'A3', 'A4', 'A5',
#        'A6', 'A7', 'A8', 'A9', 'A10', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7',
#        'C8', 'C9', 'C10', 'O1', 'O2', 'O3', 'O4', 'O5', 'O6', 'O7', 'O8', 'O9',
#        'O10'],
#       dtype='object')

# %% [markdown]
# #EFA for selected columns

# %%
selected_columns = ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10',
                    'N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'N9', 'N10',
                    'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10',
                    'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10',
                    'O1', 'O2', 'O3', 'O4', 'O5', 'O6', 'O7', 'O8', 'O9', 'O10']

selected_df = df[selected_columns]

# %%
corr_matrix = selected_df.corr()
corr_matrix
# Out:
#            E1        E2        E3        E4        E5        E6        E7  \
# E1   1.000000 -0.421009  0.474275 -0.483781  0.479101 -0.346676  0.588100
# E2  -0.421009  1.000000 -0.445537  0.527723 -0.539518  0.570819 -0.479932
# E3   0.474275 -0.445537  1.000000 -0.481006  0.590660 -0.393412  0.579883
# E4  -0.483781  0.527723 -0.481006  1.000000 -0.510068  0.474928 -0.503229
# E5   0.479101 -0.539518  0.590660 -0.510068  1.000000 -0.480675  0.630796
# E6  -0.346676  0.570819 -0.393412  0.474928 -0.480675  1.000000 -0.405476
# E7   0.588100 -0.479932  0.579883 -0.503229  0.630796 -0.405476  1.000000
# E8  -0.366534  0.373481 -0.320097  0.446221 -0.344639  0.320371 -0.344825
# E9   0.455476 -0.364713  0.423473 -0.450755  0.416147 -0.330175  0.433230
# E10 -0.414282  0.463642 -0.473928  0.510477 -0.542389  0.412007 -0.533139
# N1  -0.113651  0.060808 -0.234579  0.154786 -0.126033  0.107439 -0.140447
# N2   0.151386 -0.029237  0.281804 -0.088983  0.132877 -0.050832  0.155820
# ...

# %%
# Perform factor analysis
fa = FactorAnalyzer(n_factors=10, rotation=None)
fa.fit(selected_df)

# Get the eigenvalues
eigenvalues = fa.get_eigenvalues()[0]

# Plot the scree plot
plt.plot(range(1, len(eigenvalues) + 1), eigenvalues, 'bo-', linewidth=2)
plt.xlabel('Number of Factors')
plt.ylabel('Eigenvalue')
plt.title('Scree Plot')
plt.grid(True)
plt.show()

# %%
from factor_analyzer import FactorAnalyzer

# we have selected_df as the DataFrame containing the selected columns
# Perform exploratory factor analysis
efa = FactorAnalyzer(n_factors=10, rotation=None)  # Specify the number of factors want to extract
efa.fit(selected_df)

# Get the factor loadings
factor_loadings = efa.loadings_

# Display the factor loadings
print(factor_loadings)
# Out:
# [[-5.02689388e-01  2.57729538e-01 -2.48630132e-01 -1.79703943e-01
#    2.12038584e-01  1.17206009e-01  3.56960846e-02  3.82652757e-02
#   -2.11127839e-02 -4.17702072e-03]
#  [ 4.95949089e-01 -3.37235422e-01  2.32712370e-01  1.84442447e-01
#   -1.84146393e-01  1.64051154e-01  3.45793952e-02  9.84819307e-02
#   -4.45086884e-03  2.01710376e-02]
#  [-6.96512686e-01  1.52335307e-01 -6.98099212e-02 -2.26800579e-01
#    1.02648909e-01  8.05106577e-02  7.65022539e-02  4.51603636e-02
#    4.30372358e-02  8.47035476e-02]
#  [ 5.71048315e-01 -1.91408507e-01  2.67499752e-01  2.28383771e-01
#   -2.01886206e-01  1.63164686e-01  7.48541119e-02  9.19547497e-03
#   -5.16400887e-03  1.11873057e-01]
#  [-6.45095871e-01  3.07502488e-01 -1.39504392e-01 -1.52066369e-01
#    1.98201281e-01 -9.66192540e-03  5.47443965e-02 -1.37910562e-02
#    1.97754337e-02  4.80175126e-02]
#  [ 5.43581687e-01 -2.52383059e-01  1.98335657e-01 -1.47700416e-02
# ...

# %%
# Plot the correlation matrix as a heatmap
plt.figure(figsize=(48, 36))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)

plt.title('Correlation Matrix')
plt.show()

# %%
# Transpose the factor loadings array
factor_loadings_transposed = factor_loadings.T

# Create a DataFrame for the factor loadings
factor_loadings_df = pd.DataFrame(factor_loadings_transposed, columns=selected_columns)

# Plot the factor loadings using a heatmap
plt.figure(figsize=(48, 36))  # Adjust the figure size as needed
sns.heatmap(factor_loadings_df, cmap='coolwarm', annot=True)

plt.title('Factor Loadings of Variables')
plt.xlabel('Factors')
plt.ylabel('Variables')
plt.show()
